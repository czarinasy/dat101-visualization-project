# %%
import pandas as pd

# 1. SETTINGS AND CONSTANTS
USD_TO_PHP = 57.65

# 2. LOAD DATA
population_df = pd.read_csv('./datasets/raw/population.csv', index_col='Region', header=0, thousands=',')
population_df.index = population_df.index.str.strip()
population_df['Average Population'] = population_df.loc[:, '2015':'2024'].mean(axis=1)

gdp_df = pd.read_csv('./datasets/raw/gdp.csv', index_col='Region', header=0, thousands=',')
gdp_df.index = gdp_df.index.str.strip()
gdp_df['Average GDP'] = gdp_df.loc[:, '2015':'2024'].mean(axis=1)

emdat_df = pd.read_csv('./datasets/clean/emdat_ph_regions.csv', index_col='DisNo.', parse_dates=['Entry Date'])
emdat_df = emdat_df[emdat_df['Entry Date'].between('2015-01-01', '2024-12-31')]

# 3. TRANSFORM AND EXPLODE
emdat_df_exploded = emdat_df.copy()
emdat_df_exploded['PH Region'] = emdat_df_exploded['PH Regions'].str.split(';')
emdat_df_exploded = emdat_df_exploded.explode('PH Region').copy()
emdat_df_exploded['PH Region'] = emdat_df_exploded['PH Region'].str.strip()

# DISASTER FREQUENCY
disaster_risk_index_df = emdat_df_exploded.groupby('PH Region').size().to_frame(name='Disaster Count')
disaster_risk_index_df['Disaster Frequency'] = disaster_risk_index_df['Disaster Count'] / 10
df_min, df_max = disaster_risk_index_df['Disaster Frequency'].min(), disaster_risk_index_df['Disaster Frequency'].max()
disaster_risk_index_df['Disaster Frequency (Normalized)'] = ((disaster_risk_index_df['Disaster Frequency'] - df_min) / (df_max - df_min)) * 100

# 5. HUMAN IMPACT (POPULATION WEIGHTED)
emdat_df_exploded['Region_Pop'] = emdat_df_exploded['PH Region'].map(population_df['Average Population'])
total_pop_per_disaster = emdat_df_exploded.groupby(level=0)['Region_Pop'].transform('sum')
emdat_df_exploded['Human_Share'] = emdat_df_exploded['Region_Pop'] / total_pop_per_disaster

emdat_df_exploded['Weighted Affected'] = emdat_df_exploded['Human_Share'] * emdat_df_exploded['Total Affected']
disaster_risk_index_df['Total Affected'] = emdat_df_exploded.groupby('PH Region')['Weighted Affected'].sum()
disaster_risk_index_df['Average Population'] = population_df['Average Population']
disaster_risk_index_df['Human Impact'] = disaster_risk_index_df['Total Affected'] / disaster_risk_index_df['Average Population']

hi_min, hi_max = disaster_risk_index_df['Human Impact'].min(), disaster_risk_index_df['Human Impact'].max()
disaster_risk_index_df['Human Impact (Normalized)'] = ((disaster_risk_index_df['Human Impact'] - hi_min) / (hi_max - hi_min)) * 100

# 6. ECONOMIC IMPACT (GDP WEIGHTED)
# Map GDP for splitting damage
emdat_df_exploded['Region_GDP_Val'] = emdat_df_exploded['PH Region'].map(gdp_df['Average GDP'])
total_gdp_per_disaster = emdat_df_exploded.groupby(level=0)['Region_GDP_Val'].transform('sum')
emdat_df_exploded['Economic_Share'] = emdat_df_exploded['Region_GDP_Val'] / total_gdp_per_disaster

# Apply Economic Share to Damage
emdat_df_exploded['Weighted Damage USD'] = emdat_df_exploded['Economic_Share'] * emdat_df_exploded["Total Damage, Adjusted ('000 US$)"]
weighted_damage_total_usd = emdat_df_exploded.groupby('PH Region')['Weighted Damage USD'].sum()

# Convert and Store
disaster_risk_index_df['Total Damage (Adjusted PHP)'] = (weighted_damage_total_usd * 1000) * USD_TO_PHP
disaster_risk_index_df['Average GDP'] = gdp_df['Average GDP']
disaster_risk_index_df['Economic Impact'] = disaster_risk_index_df['Total Damage (Adjusted PHP)'] / disaster_risk_index_df['Average GDP']

ei_min, ei_max = disaster_risk_index_df['Economic Impact'].min(), disaster_risk_index_df['Economic Impact'].max()
disaster_risk_index_df['Economic Impact (Normalized)'] = ((disaster_risk_index_df['Economic Impact'] - ei_min) / (ei_max - ei_min)) * 100

# 7. FINAL DISASTER RISK INDEX
disaster_risk_index_df['Disaster Risk Score'] = (
    (disaster_risk_index_df['Disaster Frequency (Normalized)'] ** 1/3) +
    (1/3 * disaster_risk_index_df['Human Impact (Normalized)'] ** 1/3) +
    (1/3 * disaster_risk_index_df['Economic Impact (Normalized)'] ** 1/3)
)

# 8. OUTPUT
pd.set_option('display.float_format', '{:.2f}'.format)
disaster_risk_index_df.to_csv('./datasets/clean/disaster_risk_index.csv', index='PH Region')
display(disaster_risk_index_df)
# Out:
#                                                  Disaster Count  \
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao              24
# Cordillera Administrative Region                             36
# National Capital Region                                      23
# Region I - Ilocos Region                                     39
# Region II - Cagayan Valley                                   45
# Region III - Central Luzon                                   39
# Region IVA - CALABARZON                                      45
# Region IVB - MIMAROPA                                        36
# Region IX - Zamboanga Peninsula                              21
# Region V - Bicol                                             41
# Region VI - Western Visayas                                  37
# Region VII - Central Visayas                                 26
# Region VIII - Eastern Visayas                                41
# Region X - Northern Mindanao                                 32
# Region XI - Davao                                            29
# Region XII - SOCCSKSARGEN                                    23
# Region XIII - Caraga                                         34
#
#                                                  Disaster Frequency  \
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao                2.40
# Cordillera Administrative Region                               3.60
# National Capital Region                                        2.30
# Region I - Ilocos Region                                       3.90
# Region II - Cagayan Valley                                     4.50
# Region III - Central Luzon                                     3.90
# Region IVA - CALABARZON                                        4.50
# Region IVB - MIMAROPA                                          3.60
# Region IX - Zamboanga Peninsula                                2.10
# Region V - Bicol                                               4.10
# Region VI - Western Visayas                                    3.70
# Region VII - Central Visayas                                   2.60
# Region VIII - Eastern Visayas                                  4.10
# Region X - Northern Mindanao                                   3.20
# Region XI - Davao                                              2.90
# Region XII - SOCCSKSARGEN                                      2.30
# Region XIII - Caraga                                           3.40
#
#                                                  Disaster Frequency (Normalized)  \
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao                            12.50
# Cordillera Administrative Region                                           62.50
# National Capital Region                                                     8.33
# Region I - Ilocos Region                                                   75.00
# Region II - Cagayan Valley                                                100.00
# Region III - Central Luzon                                                 75.00
# Region IVA - CALABARZON                                                   100.00
# Region IVB - MIMAROPA                                                      62.50
# Region IX - Zamboanga Peninsula                                             0.00
# Region V - Bicol                                                           83.33
# Region VI - Western Visayas                                                66.67
# Region VII - Central Visayas                                               20.83
# Region VIII - Eastern Visayas                                              83.33
# Region X - Northern Mindanao                                               45.83
# Region XI - Davao                                                          33.33
# Region XII - SOCCSKSARGEN                                                   8.33
# Region XIII - Caraga                                                       54.17
#
#                                                  Total Affected  \
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao      1657727.37
# Cordillera Administrative Region                     1918905.60
# National Capital Region                              7349941.48
# Region I - Ilocos Region                             5930111.93
# Region II - Cagayan Valley                           4682848.65
# Region III - Central Luzon                          10758019.55
# Region IVA - CALABARZON                             15188984.14
# Region IVB - MIMAROPA                                4024816.87
# Region IX - Zamboanga Peninsula                      1110317.87
# Region V - Bicol                                     5680726.69
# Region VI - Western Visayas                          7040339.67
# Region VII - Central Visayas                         6204636.02
# Region VIII - Eastern Visayas                        6767875.02
# Region X - Northern Mindanao                         5584694.21
# Region XI - Davao                                    6470285.37
# Region XII - SOCCSKSARGEN                            2024341.35
# Region XIII - Caraga                                 2525749.19
#
#                                                  Average Population  \
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao          4305348.80
# Cordillera Administrative Region                         1792257.30
# National Capital Region                                 13523820.50
# Region I - Ilocos Region                                 5259669.10
# Region II - Cagayan Valley                               3653605.20
# Region III - Central Luzon                              12262436.30
# Region IVA - CALABARZON                                 16003842.20
# Region IVB - MIMAROPA                                    3177330.10
# Region IX - Zamboanga Peninsula                          3951319.10
# Region V - Bicol                                         6051966.90
# Region VI - Western Visayas                              7578628.20
# Region VII - Central Visayas                             7808667.00
# Region VIII - Eastern Visayas                            4586142.70
# Region X - Northern Mindanao                             4996616.20
# Region XI - Davao                                        5217327.30
# Region XII - SOCCSKSARGEN                                4817704.30
# Region XIII - Caraga                                     2768065.80
#
#                                                  Human Impact  \
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao          0.39
# Cordillera Administrative Region                         1.07
# National Capital Region                                  0.54
# Region I - Ilocos Region                                 1.13
# Region II - Cagayan Valley                               1.28
# Region III - Central Luzon                               0.88
# Region IVA - CALABARZON                                  0.95
# Region IVB - MIMAROPA                                    1.27
# Region IX - Zamboanga Peninsula                          0.28
# Region V - Bicol                                         0.94
# Region VI - Western Visayas                              0.93
# Region VII - Central Visayas                             0.79
# Region VIII - Eastern Visayas                            1.48
# Region X - Northern Mindanao                             1.12
# Region XI - Davao                                        1.24
# Region XII - SOCCSKSARGEN                                0.42
# Region XIII - Caraga                                     0.91
#
#                                                  Human Impact (Normalized)  \
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao                       8.71
# Cordillera Administrative Region                                     66.10
# National Capital Region                                              21.97
# Region I - Ilocos Region                                             70.85
# Region II - Cagayan Valley                                           83.76
# Region III - Central Luzon                                           49.91
# Region IVA - CALABARZON                                              55.92
# Region IVB - MIMAROPA                                                82.51
# Region IX - Zamboanga Peninsula                                       0.00
# Region V - Bicol                                                     55.05
# Region VI - Western Visayas                                          54.24
# Region VII - Central Visayas                                         42.99
# Region VIII - Eastern Visayas                                       100.00
# Region X - Northern Mindanao                                         70.03
# Region XI - Davao                                                    80.28
# Region XII - SOCCSKSARGEN                                            11.65
# Region XIII - Caraga                                                 52.85
#
#                                                  Total Damage (Adjusted PHP)  \
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao                1724737068.72
# Cordillera Administrative Region                              36427336129.61
# National Capital Region                                       74287916533.61
# Region I - Ilocos Region                                      85924994379.99
# Region II - Cagayan Valley                                    57846158113.77
# Region III - Central Luzon                                    42001765744.34
# Region IVA - CALABARZON                                       62682672729.68
# Region IVB - MIMAROPA                                         11865653701.81
# Region IX - Zamboanga Peninsula                                2235580552.33
# Region V - Bicol                                              10523960790.36
# Region VI - Western Visayas                                    7820917237.70
# Region VII - Central Visayas                                  26266049708.73
# Region VIII - Eastern Visayas                                 19179184821.38
# Region X - Northern Mindanao                                  21398671203.36
# Region XI - Davao                                             25432428702.43
# Region XII - SOCCSKSARGEN                                      3305263427.96
# Region XIII - Caraga                                           8559197854.23
#
#                                                   Average GDP  \
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao  280770554.00
# Cordillera Administrative Region                 335675496.48
# National Capital Region                         6333211338.33
# Region I - Ilocos Region                         657600124.81
# Region II - Cagayan Valley                       419497031.27
# Region III - Central Luzon                      2175810167.00
# Region IVA - CALABARZON                         2875277272.17
# Region IVB - MIMAROPA                            392869888.97
# Region IX - Zamboanga Peninsula                  432961781.85
# Region V - Bicol                                 576758546.83
# Region VI - Western Visayas                      862592826.85
# Region VII - Central Visayas                    1235808611.84
# Region VIII - Eastern Visayas                    470603261.06
# Region X - Northern Mindanao                     943280318.78
# Region XI - Davao                                977193982.57
# Region XII - SOCCSKSARGEN                        508758825.71
# Region XIII - Caraga                             331885325.58
#
#                                                  Economic Impact  \
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao             6.14
# Cordillera Administrative Region                          108.52
# National Capital Region                                    11.73
# Region I - Ilocos Region                                  130.66
# Region II - Cagayan Valley                                137.89
# Region III - Central Luzon                                 19.30
# Region IVA - CALABARZON                                    21.80
# Region IVB - MIMAROPA                                      30.20
# Region IX - Zamboanga Peninsula                             5.16
# Region V - Bicol                                           18.25
# Region VI - Western Visayas                                 9.07
# Region VII - Central Visayas                               21.25
# Region VIII - Eastern Visayas                              40.75
# Region X - Northern Mindanao                               22.69
# Region XI - Davao                                          26.03
# Region XII - SOCCSKSARGEN                                   6.50
# Region XIII - Caraga                                       25.79
#
#                                                  Economic Impact (Normalized)  \
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao                          0.74
# Cordillera Administrative Region                                        77.87
# National Capital Region                                                  4.95
# Region I - Ilocos Region                                                94.55
# Region II - Cagayan Valley                                             100.00
# Region III - Central Luzon                                              10.65
# Region IVA - CALABARZON                                                 12.53
# Region IVB - MIMAROPA                                                   18.86
# Region IX - Zamboanga Peninsula                                          0.00
# Region V - Bicol                                                         9.86
# Region VI - Western Visayas                                              2.94
# Region VII - Central Visayas                                            12.12
# Region VIII - Eastern Visayas                                           26.81
# Region X - Northern Mindanao                                            13.20
# Region XI - Davao                                                       15.72
# Region XII - SOCCSKSARGEN                                                1.00
# Region XIII - Caraga                                                    15.54
#
#                                                  Disaster Risk Score
# PH Region
# Bangsamoro Autonomous Region in Muslim Mindanao                 5.22
# Cordillera Administrative Region                               36.83
# National Capital Region                                         5.77
# Region I - Ilocos Region                                       43.38
# Region II - Cagayan Valley                                     53.75
# Region III - Central Luzon                                     31.73
# Region IVA - CALABARZON                                        40.94
# Region IVB - MIMAROPA                                          32.10
# Region IX - Zamboanga Peninsula                                 0.00
# Region V - Bicol                                               34.99
# Region VI - Western Visayas                                    28.58
# Region VII - Central Visayas                                   13.07
# Region VIII - Eastern Visayas                                  41.87
# Region X - Northern Mindanao                                   24.53
# Region XI - Davao                                              21.78
# Region XII - SOCCSKSARGEN                                       4.18
# Region XIII - Caraga                                           25.65
