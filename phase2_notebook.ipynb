# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import re

geolocator = Nominatim(user_agent="my_app")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)



def clean_location(loc):
    if pd.isna(loc):
        return None

    # Lowercase for uniformity
    loc = loc.lower()

    # Remove text in parentheses
    loc = re.sub(r"\(.*?\)", "", loc)

    # Split on commas, semicolons, quotes, periods
    loc = re.split(r"[;,.\"]", loc)[0]

    # Remove words like province, region, district, island
    loc = re.sub(r"\b(province|region|district|isl|island)\b", "", loc)

    return loc.strip().title()



# def get_region(address):
#     location = geocode(address, addressdetails=True)
#     if location:
#         # The key for 'region' varies by country (state, province, region)
#         address_dict = location.raw.get('address', {})
#         return address_dict.get('state') or address_dict.get('region')
#     return None

df = pd.read_csv('./datasets/raw/emdat.csv', index_col="DisNo.")
df_small = df.iloc[:10].copy()
display(df_small)
# df_small['Region'] = df_small['Location'].apply(get_region)
display(df_small)

df_small["CleanLocation"] = df_small["Location"].apply(clean_location)
df_small[["Location", "CleanLocation"]]
# Out:
#               Historic Classification Key Disaster Group Disaster Subgroup  \
# DisNo.
# 2000-0396-PHL       No    nat-met-sto-tro        Natural    Meteorological
# 2000-0414-PHL       No    nat-hyd-mmw-sub        Natural      Hydrological
# 2000-0597-PHL       No    nat-hyd-flo-coa        Natural      Hydrological
# 2000-0783-PHL       No    nat-bio-epi-dis        Natural        Biological
# 2022-0832-PHL       No    nat-hyd-flo-flo        Natural      Hydrological
# 2020-0463-PHL       No    nat-met-sto-tro        Natural    Meteorological
# 2019-0162-PHL       No    nat-geo-ear-gro        Natural       Geophysical
# 2019-0489-PHL       No    nat-geo-ear-gro        Natural       Geophysical
# 2019-0619-PHL       No    nat-geo-ear-gro        Natural       Geophysical
# 2017-0050-PHL       No    nat-geo-ear-gro        Natural       Geophysical
#
#                      Disaster Type              Disaster Subtype  \
# DisNo.
# 2000-0396-PHL                Storm              Tropical cyclone
# 2000-0414-PHL  Mass movement (wet)       Sudden Subsidence (wet)
# 2000-0597-PHL                Flood                 Coastal flood
# 2000-0783-PHL             Epidemic  Infectious disease (General)
# 2022-0832-PHL                Flood               Flood (General)
# 2020-0463-PHL                Storm              Tropical cyclone
# 2019-0162-PHL           Earthquake               Ground movement
# 2019-0489-PHL           Earthquake               Ground movement
# 2019-0619-PHL           Earthquake               Ground movement
# 2017-0050-PHL           Earthquake               Ground movement
#
#                                                     External IDs  \
# DisNo.
# 2000-0396-PHL                                                NaN
# 2000-0414-PHL                                                NaN
# 2000-0597-PHL                                                NaN
# 2000-0783-PHL                                                NaN
# 2022-0832-PHL                                                NaN
# 2020-0463-PHL                               GLIDE:TC-2020-000214
# 2019-0162-PHL  GLIDE:EQ-2019-000035|GLIDE:EQ-2019-000036|USGS...
# 2019-0489-PHL                                    USGS:us70005ulm
# 2019-0619-PHL               GLIDE:EQ-2019-000168|USGS:us60006rp9
# 2017-0050-PHL               GLIDE:EQ-2017-000016|USGS:us20008ixa
#
#                               Event Name  ISO      Country  ...  \
# DisNo.                                                      ...
# 2000-0396-PHL                     Kirogi  PHL  Philippines  ...
# 2000-0414-PHL                    Garbage  PHL  Philippines  ...
# 2000-0597-PHL                     Maring  PHL  Philippines  ...
# 2000-0783-PHL  Acute diarrhoeal syndrome  PHL  Philippines  ...
# 2022-0832-PHL                        NaN  PHL  Philippines  ...
# 2020-0463-PHL     Typhoon 'Goni' (Rolly)  PHL  Philippines  ...
# 2019-0162-PHL                        NaN  PHL  Philippines  ...
# 2019-0489-PHL                        NaN  PHL  Philippines  ...
# 2019-0619-PHL                        NaN  PHL  Philippines  ...
# 2017-0050-PHL                        NaN  PHL  Philippines  ...
#
#               Reconstruction Costs, Adjusted ('000 US$)  \
# DisNo.
# 2000-0396-PHL                                       NaN
# 2000-0414-PHL                                       NaN
# 2000-0597-PHL                                       NaN
# 2000-0783-PHL                                       NaN
# 2022-0832-PHL                                       NaN
# 2020-0463-PHL                                       NaN
# 2019-0162-PHL                                       NaN
# 2019-0489-PHL                                       NaN
# 2019-0619-PHL                                       NaN
# 2017-0050-PHL                                       NaN
#
#               Insured Damage ('000 US$) Insured Damage, Adjusted ('000 US$)  \
# DisNo.
# 2000-0396-PHL                       NaN                                 NaN
# 2000-0414-PHL                       NaN                                 NaN
# 2000-0597-PHL                       NaN                                 NaN
# 2000-0783-PHL                       NaN                                 NaN
# 2022-0832-PHL                       NaN                                 NaN
# 2020-0463-PHL                       NaN                                 NaN
# 2019-0162-PHL                       NaN                                 NaN
# 2019-0489-PHL                       NaN                                 NaN
# 2019-0619-PHL                       NaN                                 NaN
# 2017-0050-PHL                       NaN                                 NaN
#
#               Total Damage ('000 US$) Total Damage, Adjusted ('000 US$)  \
# DisNo.
# 2000-0396-PHL                  7500.0                           13662.0
# 2000-0414-PHL                     NaN                               NaN
# 2000-0597-PHL                     NaN                               NaN
# 2000-0783-PHL                     NaN                               NaN
# 2022-0832-PHL                 11000.0                           11791.0
# 2020-0463-PHL                503294.0                          610011.0
# 2019-0162-PHL                 50000.0                           61349.0
# 2019-0489-PHL                     NaN                               NaN
# 2019-0619-PHL                     NaN                               NaN
# 2017-0050-PHL                 13974.0                           17883.0
#
#                      CPI                                        Admin Units  \
# DisNo.
# 2000-0396-PHL  54.895152  [{"adm1_code":2355,"adm1_name":"National Capit...
# 2000-0414-PHL  54.895152  [{"adm2_code":24210,"adm2_name":"Metropolitan ...
# 2000-0597-PHL  54.895152  [{"adm2_code":24210,"adm2_name":"Metropolitan ...
# 2000-0783-PHL  54.895152                                                NaN
# 2022-0832-PHL  93.294607                                                NaN
# 2020-0463-PHL  82.505684  [{"adm1_code":2354,"adm1_name":"Cordillera Adm...
# 2019-0162-PHL  81.500309       [{"adm2_code":24225,"adm2_name":"Zambales"}]
# 2019-0489-PHL  81.500309  [{"adm2_code":24273,"adm2_name":"North Cotabat...
# 2019-0619-PHL  81.500309  [{"adm2_code":24268,"adm2_name":"Davao Del Sur"}]
# 2017-0050-PHL  78.141002  [{"adm2_code":67169,"adm2_name":"Surigao Del N...
#
#                                                 GADM Admin Units  Entry Date  \
# DisNo.
# 2000-0396-PHL                                                NaN  2003-07-01
# 2000-0414-PHL                                                NaN  2005-04-24
# 2000-0597-PHL                                                NaN  2004-10-21
# 2000-0783-PHL                                                NaN  2003-07-01
# 2022-0832-PHL  [{"gid_1":"PHL.14_1","migration_date":"2025-12...  2023-01-02
# 2020-0463-PHL  [{"gid_1":"PHL.10_1","migration_date":"2025-12...  2020-11-03
# 2019-0162-PHL  [{"gid_2":"PHL.78.10_1","migration_date":"2025...  2019-04-23
# 2019-0489-PHL  [{"gid_2":"PHL.53.10_1","migration_date":"2025...  2019-10-22
# 2019-0619-PHL                                                NaN  2019-12-16
# 2017-0050-PHL  [{"gid_2":"PHL.74.10_1","migration_date":"2025...  2017-02-17
#
#                Last Update
# DisNo.
# 2000-0396-PHL   2023-09-25
# 2000-0414-PHL   2023-09-25
# 2000-0597-PHL   2023-09-25
# 2000-0783-PHL   2023-09-25
# 2022-0832-PHL   2026-01-16
# 2020-0463-PHL   2025-12-20
# 2019-0162-PHL   2026-01-25
# 2019-0489-PHL   2026-01-25
# 2019-0619-PHL   2026-01-25
# 2017-0050-PHL   2026-01-25
#
# [10 rows x 46 columns]
#               Historic Classification Key Disaster Group Disaster Subgroup  \
# DisNo.
# 2000-0396-PHL       No    nat-met-sto-tro        Natural    Meteorological
# 2000-0414-PHL       No    nat-hyd-mmw-sub        Natural      Hydrological
# 2000-0597-PHL       No    nat-hyd-flo-coa        Natural      Hydrological
# 2000-0783-PHL       No    nat-bio-epi-dis        Natural        Biological
# 2022-0832-PHL       No    nat-hyd-flo-flo        Natural      Hydrological
# 2020-0463-PHL       No    nat-met-sto-tro        Natural    Meteorological
# 2019-0162-PHL       No    nat-geo-ear-gro        Natural       Geophysical
# 2019-0489-PHL       No    nat-geo-ear-gro        Natural       Geophysical
# 2019-0619-PHL       No    nat-geo-ear-gro        Natural       Geophysical
# 2017-0050-PHL       No    nat-geo-ear-gro        Natural       Geophysical
#
#                      Disaster Type              Disaster Subtype  \
# DisNo.
# 2000-0396-PHL                Storm              Tropical cyclone
# 2000-0414-PHL  Mass movement (wet)       Sudden Subsidence (wet)
# 2000-0597-PHL                Flood                 Coastal flood
# 2000-0783-PHL             Epidemic  Infectious disease (General)
# 2022-0832-PHL                Flood               Flood (General)
# 2020-0463-PHL                Storm              Tropical cyclone
# 2019-0162-PHL           Earthquake               Ground movement
# 2019-0489-PHL           Earthquake               Ground movement
# 2019-0619-PHL           Earthquake               Ground movement
# 2017-0050-PHL           Earthquake               Ground movement
#
#                                                     External IDs  \
# DisNo.
# 2000-0396-PHL                                                NaN
# 2000-0414-PHL                                                NaN
# 2000-0597-PHL                                                NaN
# 2000-0783-PHL                                                NaN
# 2022-0832-PHL                                                NaN
# 2020-0463-PHL                               GLIDE:TC-2020-000214
# 2019-0162-PHL  GLIDE:EQ-2019-000035|GLIDE:EQ-2019-000036|USGS...
# 2019-0489-PHL                                    USGS:us70005ulm
# 2019-0619-PHL               GLIDE:EQ-2019-000168|USGS:us60006rp9
# 2017-0050-PHL               GLIDE:EQ-2017-000016|USGS:us20008ixa
#
#                               Event Name  ISO      Country  ...  \
# DisNo.                                                      ...
# 2000-0396-PHL                     Kirogi  PHL  Philippines  ...
# 2000-0414-PHL                    Garbage  PHL  Philippines  ...
# 2000-0597-PHL                     Maring  PHL  Philippines  ...
# 2000-0783-PHL  Acute diarrhoeal syndrome  PHL  Philippines  ...
# 2022-0832-PHL                        NaN  PHL  Philippines  ...
# 2020-0463-PHL     Typhoon 'Goni' (Rolly)  PHL  Philippines  ...
# 2019-0162-PHL                        NaN  PHL  Philippines  ...
# 2019-0489-PHL                        NaN  PHL  Philippines  ...
# 2019-0619-PHL                        NaN  PHL  Philippines  ...
# 2017-0050-PHL                        NaN  PHL  Philippines  ...
#
#               Reconstruction Costs, Adjusted ('000 US$)  \
# DisNo.
# 2000-0396-PHL                                       NaN
# 2000-0414-PHL                                       NaN
# 2000-0597-PHL                                       NaN
# 2000-0783-PHL                                       NaN
# 2022-0832-PHL                                       NaN
# 2020-0463-PHL                                       NaN
# 2019-0162-PHL                                       NaN
# 2019-0489-PHL                                       NaN
# 2019-0619-PHL                                       NaN
# 2017-0050-PHL                                       NaN
#
#               Insured Damage ('000 US$) Insured Damage, Adjusted ('000 US$)  \
# DisNo.
# 2000-0396-PHL                       NaN                                 NaN
# 2000-0414-PHL                       NaN                                 NaN
# 2000-0597-PHL                       NaN                                 NaN
# 2000-0783-PHL                       NaN                                 NaN
# 2022-0832-PHL                       NaN                                 NaN
# 2020-0463-PHL                       NaN                                 NaN
# 2019-0162-PHL                       NaN                                 NaN
# 2019-0489-PHL                       NaN                                 NaN
# 2019-0619-PHL                       NaN                                 NaN
# 2017-0050-PHL                       NaN                                 NaN
#
#               Total Damage ('000 US$) Total Damage, Adjusted ('000 US$)  \
# DisNo.
# 2000-0396-PHL                  7500.0                           13662.0
# 2000-0414-PHL                     NaN                               NaN
# 2000-0597-PHL                     NaN                               NaN
# 2000-0783-PHL                     NaN                               NaN
# 2022-0832-PHL                 11000.0                           11791.0
# 2020-0463-PHL                503294.0                          610011.0
# 2019-0162-PHL                 50000.0                           61349.0
# 2019-0489-PHL                     NaN                               NaN
# 2019-0619-PHL                     NaN                               NaN
# 2017-0050-PHL                 13974.0                           17883.0
#
#                      CPI                                        Admin Units  \
# DisNo.
# 2000-0396-PHL  54.895152  [{"adm1_code":2355,"adm1_name":"National Capit...
# 2000-0414-PHL  54.895152  [{"adm2_code":24210,"adm2_name":"Metropolitan ...
# 2000-0597-PHL  54.895152  [{"adm2_code":24210,"adm2_name":"Metropolitan ...
# 2000-0783-PHL  54.895152                                                NaN
# 2022-0832-PHL  93.294607                                                NaN
# 2020-0463-PHL  82.505684  [{"adm1_code":2354,"adm1_name":"Cordillera Adm...
# 2019-0162-PHL  81.500309       [{"adm2_code":24225,"adm2_name":"Zambales"}]
# 2019-0489-PHL  81.500309  [{"adm2_code":24273,"adm2_name":"North Cotabat...
# 2019-0619-PHL  81.500309  [{"adm2_code":24268,"adm2_name":"Davao Del Sur"}]
# 2017-0050-PHL  78.141002  [{"adm2_code":67169,"adm2_name":"Surigao Del N...
#
#                                                 GADM Admin Units  Entry Date  \
# DisNo.
# 2000-0396-PHL                                                NaN  2003-07-01
# 2000-0414-PHL                                                NaN  2005-04-24
# 2000-0597-PHL                                                NaN  2004-10-21
# 2000-0783-PHL                                                NaN  2003-07-01
# 2022-0832-PHL  [{"gid_1":"PHL.14_1","migration_date":"2025-12...  2023-01-02
# 2020-0463-PHL  [{"gid_1":"PHL.10_1","migration_date":"2025-12...  2020-11-03
# 2019-0162-PHL  [{"gid_2":"PHL.78.10_1","migration_date":"2025...  2019-04-23
# 2019-0489-PHL  [{"gid_2":"PHL.53.10_1","migration_date":"2025...  2019-10-22
# 2019-0619-PHL                                                NaN  2019-12-16
# 2017-0050-PHL  [{"gid_2":"PHL.74.10_1","migration_date":"2025...  2017-02-17
#
#                Last Update
# DisNo.
# 2000-0396-PHL   2023-09-25
# 2000-0414-PHL   2023-09-25
# 2000-0597-PHL   2023-09-25
# 2000-0783-PHL   2023-09-25
# 2022-0832-PHL   2026-01-16
# 2020-0463-PHL   2025-12-20
# 2019-0162-PHL   2026-01-25
# 2019-0489-PHL   2026-01-25
# 2019-0619-PHL   2026-01-25
# 2017-0050-PHL   2026-01-25
#
# [10 rows x 46 columns]
#                                                         Location  \
# DisNo.
# 2000-0396-PHL             National Capital region (NCR) province
# 2000-0414-PHL  Metropolitan Manila district (National Capital...
# 2000-0597-PHL        Metropolitan Manila district (NCR province)
# 2000-0783-PHL                                          Zamboanga
# 2022-0832-PHL  Mimaropa, Bicol, Eastern Visayas, Zamboanga Pe...
# 2020-0463-PHL  Calabarzon, Mimaropa, Bicol Regions; NCR, II, ...
# 2019-0162-PHL                             Castillejos (Zambales)
# 2019-0489-PHL          North Cotabato Province (Mindanao Island)
# 2019-0619-PHL  Davao del Sur Province (Davao Region, Mindanao...
# 2017-0050-PHL  Surigao Del Norte district (Region XIII (Carag...
#
#                          CleanLocation
# DisNo.
# 2000-0396-PHL         National Capital
# 2000-0414-PHL  Metropolitan Manila   )
# 2000-0597-PHL      Metropolitan Manila
# 2000-0783-PHL                Zamboanga
# 2022-0832-PHL                 Mimaropa
# 2020-0463-PHL               Calabarzon
# 2019-0162-PHL              Castillejos
# 2019-0489-PHL           North Cotabato
# 2019-0619-PHL            Davao Del Sur
# 2017-0050-PHL    Surigao Del Norte   )

# %%
REGIONS = {
    "i": "Region I - Ilocos Region",
    "ilocos": "Region I - Ilocos Region",

    "ii": "Region II - Cagayan Valley",
    "cagayan": "Region II - Cagayan Valley",

    "iii": "Region III - Central Luzon",
    "centralluzon": "Region III - Central Luzon",

    "iva": "Region IVA - CALABARZON",
    "iv": "Region IVA - CALABARZON",
    "iv-a": "Region IVA - CALABARZON",
    "calabarzon": "Region IVA - CALABARZON",

    "v": "Region V - Bicol",
    "bicol": "Region V - Bicol",

    "vi": "Region VI - Western Visayas",
    "westernvisayas": "Region VI - Western Visayas",

    "vii": "Region VII - Central Visayas",
    "centralvisayas": "Region VII - Central Visayas",

    "viii": "Region VIII - Eastern Visayas",
    "easternvisayas": "Region VIII - Eastern Visayas",

    "ix": "Region IX - Zamboanga Peninsula",
    "zamboanga": "Region IX - Zamboanga Peninsula",

    "x": "Region X - Northern Mindanao",
    "northernmindanao": "Region X - Northern Mindanao",

    "xi": "Region XI - Davao",
    "davao": "Region XI - Davao",

    "xii": "Region XII - SOCCSKSARGEN",
    "soccsksargen": "Region XII - SOCCSKSARGEN",

    "ncr": "National Capital Region",
    "nationalcapital": "National Capital Region",

    "car": "Cordillera Administrative Region",
    "cordillera": "Cordillera Administrative Region",

    "xiii": "Region XIII - Caraga",
    "caraga": "Region XIII - Caraga",

    "armm": "Bangsamoro Autonomous Region in Muslim Mindanao",
    "barmm": "Bangsamoro Autonomous Region in Muslim Mindanao",

    "ivb": "Region IVB - MIMAROPA",
    "iv-b": "Region IVB - MIMAROPA",
    "mimaropa": "Region IVB - MIMAROPA",
}

def remove_fillers(loc: str) -> str:
    loc = loc.strip()
    fillers = ["region", "regions", "province", "city", "valley", "peninsula", "district"]

    if not loc:
        return ""
    # Create regex pattern: \b = word boundary
    pattern = r"\b(?:{})\b".format("|".join(fillers))

    # Replace filler words with empty string
    cleaned = re.sub(pattern, "", loc, flags=re.IGNORECASE)
    # Remove extra whitespace
    cleaned = " ".join(cleaned.split())

    return cleaned

def extract_region_number(loc: str):
    """
    Check if token starts with 'Region' + Roman numeral,
    and return the numeral if it exists.
    """
    pattern = r"^Region\s+([IVXLCDM]+)\b"
    match = re.search(pattern, loc, flags=re.IGNORECASE)
    if match:
        return match.group(1)  # The Roman numeral
    return None



def clean_location(loc_string: str) -> [str]:
    # Split Location string to obtain list of possible locations
    loc_string = loc_string.lower()
    # Split on comma, semicolon, "and", "&", "(" , ")"
    loc_parts = re.split(r"[;,]|\band\b|&|\(|\)", loc_string)
    # Clean whitespace and title-case
    parts = [p.strip() for p in loc_parts if p]

    locs = []

    for part in parts:
        part = remove_fillers(part)
        part = "".join(part.split())
        if part in REGIONS:
            locs.append(REGIONS[part])
        elif extract_region_number(part):
            locs.append(REGIONS[extract_region_number(part)])



    # print(set(locs))
    return set(locs)

df = pd.read_csv('./datasets/raw/emdat.csv')


# Apply your clean_location function first
df['CleanedLocations'] = df['Location'].dropna().apply(clean_location)

# Page parameters
page = 2
chunk_size = 10
start = (page - 1) * chunk_size
end = start + chunk_size

# Slice DataFrame manually
page_df = df.iloc[start:end][['Location', 'CleanedLocations']]
pd.set_option('display.max_colwidth', None)

# Display the first page
display(page_df)
# Out:
#                                                                                                                                                                                                                                                                           Location  \
# 10                                                                                                                                                                                                 Verde Island Passage (Tingloy, Maricaban Island). Batangas and Laguna provinces
# 11                                                                                                                                                                                                                                       Kananga (Leyte Isl), Ormoc City, Carigara
# 12                                                                                                                                                                                                                                                               Cotabato Province
# 13                                                                                                                                                                                                                                          National Capital region (NCR) province
# 14  Cotabato; Datu Blah Sinsuat (Mindanao Isl.); Virac, Catanduanes, Caramoan, Camarines Sur, Buenavista, Quezon, Santa Cruz, Marinduque, San Juan, Batangas; Region III (Central Luzon), Region VI (Western Visayas), Region VII (Central Visayas), National Capital region (NCR)
# 15                                                                                                                                                                                    Abra Province (northern Luzon), Ilocos, Cordillera Administrative Region, and Cagayan Valley
# 16                                                                                                                                                                                                                                          National Capital region (NCR) province
# 17                                                                                                                                                                                                                                               Itbayat Island (Batanes Province)
# 18                                                                                                                                                                                           Davao del Sur and South Cotabato provinces; North Cotabato Province (Mindanao Island)
# 19                                                                                                                                                                                                                   Cantilan, Carmen, Carrascal, Lanuza, Madrid (Surigao del Sur)
#
#                                                                                                     CleanedLocations
# 10                                                                                                                {}
# 11                                                                                                                {}
# 12                                                                                                                {}
# 13                                                                                         {National Capital Region}
# 14  {Region III - Central Luzon, Region VI - Western Visayas, National Capital Region, Region VII - Central Visayas}
# 15                                                            {Region II - Cagayan Valley, Region I - Ilocos Region}
# 16                                                                                         {National Capital Region}
# 17                                                                                                                {}
# 18                                                                                                                {}
# 19                                                                                                                {}
